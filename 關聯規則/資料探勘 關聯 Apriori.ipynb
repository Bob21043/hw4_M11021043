# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
x = pd.read_csv("NEW交易資料集.csv",header='infer')
x= x.dropna()
movieid = x['INVOICE_NO'].tolist()
comment = x['PRODUCT_TYPE'].tolist()

combine = list(zip(movieid,comment))

# %%
all_comment = []
store = []
# c=0
for k in range(len(combine)):
    try:
        if movieid[k] == movieid[k+1]:
            store.append(comment[k])
            # c=c+1
            continue
        elif movieid[k] != movieid[k+1] and movieid[k] == movieid[k-1]:
            store.append(comment[k])
            all_comment.append(store)
            store=[]
        elif movieid[k] != movieid[k-1] and movieid[k] != movieid[k+1]:
            store.append(comment[k])
            all_comment.append(store)
            store = []
    except:
        break
print(*all_comment, sep = "\n")
# Out:
# ['CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'OTHERS', 'OTHERS']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['CPU / MPU', 'CPU / MPU']
# ['LOGIC IC', 'LOGIC IC']
# ['LINEAR IC', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'LINEAR IC', 'LINEAR IC', 'MEMORY_EMBEDED', 'LOGIC IC', 'LINEAR IC', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC']
# ['LINEAR IC']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'CPU / MPU', 'LINEAR IC']
# ['CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'CPU / MPU', 'CPU / MPU', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'CPU / MPU', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC', 'OTHERS']
# ['CHIPSET / ASP', 'CHIPSET / ASP']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['CHIPSET / ASP', 'CHIPSET / ASP']
# ['CHIPSET / ASP', 'CHIPSET / ASP']
# ['LOGIC IC']
# ['CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP']
# ['DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'CPU / MPU']
# ['LOGIC IC']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['PEMCO', 'PEMCO']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['LOGIC IC', 'LOGIC IC']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'OTHERS', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['OPTICAL AND SENSOR']
# ['DISCRETE']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['OTHERS']
# ['CPU / MPU', 'LINEAR IC', 'LINEAR IC', 'CHIPSET / ASP', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LOGIC IC', 'DISCRETE', 'LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE']
# ['CHIPSET / ASP']
# ['LINEAR IC']
# ['PEMCO']
# ['MEMORY_EMBEDED']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CHIPSET / ASP']
# ['LOGIC IC']
# ['LINEAR IC', 'MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['PEMCO']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'OTHERS', 'OTHERS', 'PEMCO']
# ['DISCRETE', 'DISCRETE', 'LINEAR IC', 'OTHERS', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'MEMORY_EMBEDED', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'LINEAR IC', 'MEMORY_EMBEDED']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['CPU / MPU']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['CHIPSET / ASP', 'CPU / MPU']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['CPU / MPU', 'CPU / MPU']
# ['LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['PEMCO']
# ['OTHERS']
# ['OPTICAL AND SENSOR']
# ['LOGIC IC']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CHIPSET / ASP']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'DISCRETE']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['PEMCO']
# ['CHIPSET / ASP']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'DISCRETE']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['LOGIC IC']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['LOGIC IC']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC']
# ['DISCRETE']
# ['PEMCO']
# ['LINEAR IC']
# ['CHIPSET / ASP']
# ['LOGIC IC']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['DISCRETE']
# ['OTHERS', 'OTHERS', 'OTHERS', 'LINEAR IC', 'OTHERS']
# ['DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC', 'LINEAR IC', 'CPU / MPU', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'OPTICAL AND SENSOR', 'LOGIC IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LOGIC IC', 'LOGIC IC']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['CPU / MPU', 'CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'OPTICAL AND SENSOR', 'DISCRETE', 'OPTICAL AND SENSOR', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED', 'PEMCO', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['OPTICAL AND SENSOR']
# ['PEMCO', 'PEMCO']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP']
# ['CHIPSET / ASP', 'CHIPSET / ASP']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU', 'CPU / MPU']
# ['MEMORY_EMBEDED']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP', 'CHIPSET / ASP']
# ['LINEAR IC', 'LINEAR IC']
# ['OTHERS']
# ['CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC']
# ['CPU / MPU']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'DISCRETE']
# ['CHIPSET / ASP']
# ['LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CHIPSET / ASP']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['DISCRETE']
# ['DISCRETE', 'OTHERS', 'DISCRETE', 'PEMCO', 'OTHERS', 'PEMCO']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['LINEAR IC', 'LOGIC IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC']
# ['PEMCO', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'PEMCO']
# ['OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['OTHERS']
# ['MEMORY_SYSTEM']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE']
# ['PEMCO']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'PEMCO', 'DISCRETE', 'OPTICAL AND SENSOR', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC', 'LINEAR IC']
# ['CPU / MPU']
# ['MEMORY_EMBEDED']
# ['OPTICAL AND SENSOR']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['CPU / MPU']
# ['DISCRETE']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_SYSTEM', 'MEMORY_SYSTEM', 'MEMORY_SYSTEM']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE']
# ['DISCRETE', 'LINEAR IC', 'DISCRETE']
# ['LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_SYSTEM']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'MEMORY_EMBEDED', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'OPTICAL AND SENSOR', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE', 'OPTICAL AND SENSOR']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['OPTICAL AND SENSOR']
# ['PEMCO']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['MEMORY_SYSTEM', 'MEMORY_SYSTEM']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'CPU / MPU', 'CPU / MPU', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'CPU / MPU', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['MEMORY_SYSTEM']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LOGIC IC']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['OTHERS']
# ['PEMCO', 'PEMCO']
# ['PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED']
# ['MEMORY_SYSTEM', 'MEMORY_SYSTEM', 'MEMORY_SYSTEM', 'CPU / MPU', 'CHIPSET / ASP', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LOGIC IC']
# ['LOGIC IC', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR', 'DISCRETE', 'OPTICAL AND SENSOR', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'OPTICAL AND SENSOR', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['OPTICAL AND SENSOR']
# ['LOGIC IC']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'DISCRETE', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE']
# ['CPU / MPU']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['PEMCO', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC']
# ['CPU / MPU']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['LOGIC IC']
# ['OPTICAL AND SENSOR']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['CPU / MPU', 'CPU / MPU']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['CPU / MPU']
# ['LOGIC IC']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['OPTICAL AND SENSOR']
# ['DISCRETE']
# ['DISCRETE']
# ['LOGIC IC']
# ['LOGIC IC', 'LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'PEMCO', 'DISCRETE', 'DISCRETE', 'PEMCO', 'PEMCO']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['CPU / MPU']
# ['DISCRETE', 'OPTICAL AND SENSOR', 'DISCRETE']
# ['OPTICAL AND SENSOR']
# ['DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['MEMORY_EMBEDED']
# ['LOGIC IC']
# ['MEMORY_SYSTEM', 'MEMORY_SYSTEM']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'LINEAR IC']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE', 'LOGIC IC', 'CHIPSET / ASP']
# ['DISCRETE']
# ['LINEAR IC']
# ['OTHERS', 'LOGIC IC', 'LINEAR IC']
# ['LINEAR IC']
# ['OTHERS']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['OPTICAL AND SENSOR']
# ['CPU / MPU', 'MEMORY_EMBEDED', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE']
# ['PEMCO', 'PEMCO']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'MEMORY_SYSTEM', 'DISCRETE', 'MEMORY_SYSTEM']
# ['DISCRETE', 'DISCRETE']
# ['CPU / MPU', 'CPU / MPU']
# ['CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'LOGIC IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC']
# ['MEMORY_EMBEDED', 'DISCRETE', 'MEMORY_EMBEDED']
# ['LOGIC IC']
# ['CHIPSET / ASP']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['MEMORY_SYSTEM']
# ['LINEAR IC']
# ['OPTICAL AND SENSOR']
# ['PEMCO']
# ['CPU / MPU', 'CPU / MPU']
# ['CPU / MPU', 'CPU / MPU']
# ['CPU / MPU']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['OPTICAL AND SENSOR']
# ['OPTICAL AND SENSOR']
# ['CHIPSET / ASP', 'CPU / MPU']
# ['OPTICAL AND SENSOR']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE']
# ['DISCRETE', 'LOGIC IC', 'DISCRETE', 'LOGIC IC']
# ['MEMORY_SYSTEM']
# ['DISCRETE', 'DISCRETE']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE']
# ['LOGIC IC', 'LINEAR IC']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['CPU / MPU']
# ['CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['CHIPSET / ASP', 'CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['OTHERS']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'PEMCO', 'PEMCO']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC']
# ['MEMORY_SYSTEM']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC']
# ['LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'CPU / MPU']
# ['LINEAR IC', 'LINEAR IC']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC']
# ['PEMCO']
# ['LOGIC IC', 'LOGIC IC']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['CPU / MPU']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP', 'CHIPSET / ASP']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['DISCRETE']
# ['DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC']
# ['LOGIC IC']
# ['DISCRETE']
# ['DISCRETE']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'DISCRETE', 'LINEAR IC', 'MEMORY_EMBEDED', 'DISCRETE', 'LINEAR IC', 'MEMORY_EMBEDED']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['LOGIC IC', 'LINEAR IC']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC']
# ['LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['DISCRETE']
# ['DISCRETE']
# ['LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['OTHERS']
# ['LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC']
# ['MEMORY_EMBEDED', 'LINEAR IC', 'LINEAR IC', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'DISCRETE', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'OTHERS', 'OTHERS', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE']
# ['CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['MEMORY_EMBEDED', 'LOGIC IC', 'MEMORY_EMBEDED', 'DISCRETE', 'MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ...
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['LOGIC IC']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'LOGIC IC']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CPU / MPU']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LINEAR IC', 'LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LOGIC IC']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'LINEAR IC']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'CPU / MPU']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['CPU / MPU', 'CPU / MPU']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['PEMCO', 'PEMCO']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['LINEAR IC']
# ['OTHERS']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU']
# ['OTHERS']
# ['OTHERS']
# ['CPU / MPU']
# ['OTHERS']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['OTHERS']
# ['OTHERS']
# ['OTHERS']
# ['OTHERS']
# ['OTHERS']
# ['LINEAR IC']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['LOGIC IC', 'LOGIC IC']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CPU / MPU']
# ['CPU / MPU']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['PEMCO']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['CPU / MPU']
# ['DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['LOGIC IC']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['CPU / MPU']
# ['PEMCO', 'PEMCO']
# ['DISCRETE']
# ['LINEAR IC']
# ['PEMCO']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'CHIPSET / ASP', 'CHIPSET / ASP']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CPU / MPU']
# ['LINEAR IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'MEMORY_SYSTEM', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC']
# ['LOGIC IC', 'LINEAR IC']
# ['LINEAR IC']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['CHIPSET / ASP']
# ['LOGIC IC']
# ['CPU / MPU']
# ['CPU / MPU']
# ['OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR']
# ['CHIPSET / ASP']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CPU / MPU']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['OPTICAL AND SENSOR']
# ['DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CPU / MPU']
# ['LINEAR IC']
# ['OTHERS']
# ['LINEAR IC']
# ['LINEAR IC']
# ['CHIPSET / ASP']
# ['PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE', 'LINEAR IC']
# ['PEMCO', 'PEMCO']
# ['CHIPSET / ASP']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LOGIC IC']
# ['DISCRETE', 'DISCRETE']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['CHIPSET / ASP']
# ['LINEAR IC']
# ['CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU']
# ['DISCRETE']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC', 'CPU / MPU']
# ['CPU / MPU']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['PEMCO']
# ['CPU / MPU']
# ['PEMCO', 'PEMCO']
# ['PEMCO']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LOGIC IC', 'LOGIC IC']
# ['LOGIC IC']
# ['PEMCO']
# ['PEMCO']
# ['DISCRETE']
# ['CPU / MPU', 'CPU / MPU', 'CPU / MPU']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['MEMORY_SYSTEM']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'LOGIC IC']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'LINEAR IC']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'CPU / MPU', 'LINEAR IC']
# ['LINEAR IC', 'LINEAR IC', 'CPU / MPU', 'LOGIC IC']
# ['LINEAR IC', 'LINEAR IC']
# ['CPU / MPU', 'CPU / MPU']
# ['PEMCO']
# ['PEMCO']
# ['DISCRETE']
# ['PEMCO']
# ['CPU / MPU']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE']
# ['DISCRETE']
# ['CPU / MPU']
# ['LINEAR IC']
# ['LINEAR IC', 'PEMCO', 'PEMCO']
# ['CPU / MPU']
# ['PEMCO', 'PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO', 'PEMCO', 'DISCRETE', 'PEMCO', 'DISCRETE', 'PEMCO', 'LOGIC IC', 'PEMCO', 'PEMCO', 'PEMCO', 'LOGIC IC', 'DISCRETE', 'PEMCO', 'PEMCO', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'PEMCO', 'PEMCO']
# ['LOGIC IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['LINEAR IC']
# ['DISCRETE']
# ['PEMCO']
# ['CHIPSET / ASP']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['CPU / MPU']
# ['CHIPSET / ASP']
# ['PEMCO', 'PEMCO']
# ['DISCRETE']
# ['DISCRETE']
# ['CPU / MPU']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC', 'LOGIC IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['LOGIC IC']
# ['PEMCO']
# ['LOGIC IC', 'LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['LOGIC IC']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE']
# ['DISCRETE']
# ['PEMCO', 'PEMCO']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['PEMCO', 'PEMCO']
# ['PEMCO']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['PEMCO']
# ['PEMCO']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['PEMCO']
# ['PEMCO']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE']
# ['PEMCO', 'PEMCO', 'PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['DISCRETE']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['PEMCO']
# ['LOGIC IC']
# ['OPTICAL AND SENSOR']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE']
# ['PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO', 'PEMCO']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE']
# ['PEMCO']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC', 'DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LOGIC IC', 'LINEAR IC', 'DISCRETE', 'LINEAR IC', 'DISCRETE', 'CPU / MPU', 'CPU / MPU', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC', 'LINEAR IC']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['MEMORY_EMBEDED', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['PEMCO']
# ['DISCRETE']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC']
# ['PEMCO']
# ['LINEAR IC']
# ['LINEAR IC']
# ['PEMCO']
# ['PEMCO', 'PEMCO']
# ['PEMCO', 'PEMCO', 'PEMCO']
# ['PEMCO', 'PEMCO', 'PEMCO']
# ['DISCRETE']
# ['LOGIC IC']
# ['MEMORY_EMBEDED', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC']
# ['PEMCO']
# ['PEMCO']
# ['PEMCO']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['LOGIC IC']
# ['PEMCO']
# ['CHIPSET / ASP']
# ['CHIPSET / ASP']
# ['OTHERS', 'OTHERS', 'OTHERS', 'OTHERS', 'OTHERS']
# ['OTHERS', 'OTHERS', 'OTHERS', 'OTHERS', 'OTHERS', 'OTHERS']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['OTHERS', 'OTHERS', 'OTHERS']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'MEMORY_EMBEDED', 'CPU / MPU']
# ['DISCRETE']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['OTHERS', 'OTHERS', 'OTHERS']
# ['LOGIC IC', 'DISCRETE', 'LOGIC IC']
# ['LOGIC IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['LOGIC IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['CHIPSET / ASP', 'OTHERS']
# ['LOGIC IC']
# ['OTHERS']
# ['CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU']
# ['PEMCO']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LOGIC IC', 'LOGIC IC']
# ['OPTICAL AND SENSOR']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['OTHERS', 'OTHERS']
# ['OTHERS']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC', 'CPU / MPU']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['LINEAR IC', 'DISCRETE']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['PEMCO']
# ['LINEAR IC']
# ['LINEAR IC']
# ['LOGIC IC']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['DISCRETE', 'LINEAR IC', 'LOGIC IC', 'LOGIC IC']
# ['LINEAR IC']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC']
# ['DISCRETE', 'LINEAR IC', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC']
# ['CPU / MPU', 'CPU / MPU']
# ['LINEAR IC', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'LOGIC IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'PEMCO', 'PEMCO', 'PEMCO', 'LINEAR IC']
# ['DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE']
# ['DISCRETE', 'DISCRETE']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LOGIC IC', 'LOGIC IC', 'OPTICAL AND SENSOR', 'DISCRETE', 'LOGIC IC', 'LOGIC IC', 'MEMORY_EMBEDED', 'DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED', 'LOGIC IC', 'DISCRETE', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LOGIC IC', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'LINEAR IC', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'LOGIC IC']
# ['OTHERS']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'OPTICAL AND SENSOR', 'OPTICAL AND SENSOR', 'MEMORY_EMBEDED', 'DISCRETE', 'MEMORY_EMBEDED', 'DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'LOGIC IC', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['LOGIC IC', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['LOGIC IC']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['DISCRETE']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['DISCRETE']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'OPTICAL AND SENSOR', 'LOGIC IC', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'LOGIC IC', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'LOGIC IC', 'DISCRETE', 'LOGIC IC', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'LOGIC IC', 'MEMORY_EMBEDED']
# ['MEMORY_SYSTEM', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED', 'MEMORY_EMBEDED', 'DISCRETE', 'LOGIC IC', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'MEMORY_EMBEDED']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'DISCRETE', 'MEMORY_EMBEDED']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'LOGIC IC', 'LINEAR IC']
# ['DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['CPU / MPU']
# ['DISCRETE', 'DISCRETE']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'CPU / MPU', 'LINEAR IC']
# ['DISCRETE', 'OTHERS', 'LINEAR IC']
# ['LINEAR IC']
# ['CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU', 'CPU / MPU']
# ['LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['DISCRETE', 'DISCRETE', 'DISCRETE', 'DISCRETE', 'LINEAR IC', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC', 'DISCRETE', 'LOGIC IC', 'DISCRETE', 'LINEAR IC', 'MEMORY_EMBEDED', 'LINEAR IC', 'LINEAR IC']
# ['LINEAR IC']
# ['LINEAR IC', 'LINEAR IC']
# ['MEMORY_EMBEDED']
# ['DISCRETE', 'OTHERS']
# ['LINEAR IC']
# ['DISCRETE']
# ['DISCRETE']
# ['MEMORY_EMBEDED']

# %%
te = TransactionEncoder()	
df_tf = te.fit(all_comment).transform(all_comment)
	
df = pd.DataFrame(df_tf,columns=te.columns_)

frequent_itemsets = apriori(df,min_support=0.01,use_colnames=True)	
print(frequent_itemsets)
frequent_itemsets.sort_values(by='support',ascending=False,inplace=True)	

association_rule = association_rules(frequent_itemsets,metric='confidence',min_threshold=0.3)	

# association_rule = association_rules(frequent_itemsets, metric="lift", min_threshold=0.01)
print(association_rule)
# Out:
#      support                         itemsets
# 0   0.044113                  (CHIPSET / ASP)
# 1   0.110749                      (CPU / MPU)
# 2   0.257912                       (DISCRETE)
# 3   0.260405                      (LINEAR IC)
# 4   0.121544                       (LOGIC IC)
# 5   0.066718                 (MEMORY_EMBEDED)
# 6   0.021235                  (MEMORY_SYSTEM)
# 7   0.039866             (OPTICAL AND SENSOR)
# 8   0.113379                         (OTHERS)
# 9   0.119489                          (PEMCO)
# 10  0.034907            (LINEAR IC, DISCRETE)
# 11  0.026989             (LOGIC IC, DISCRETE)
# 12  0.043456            (LOGIC IC, LINEAR IC)
# 13  0.014714  (LOGIC IC, LINEAR IC, DISCRETE)
#              antecedents  consequents  antecedent support  consequent support  \
# 0             (LOGIC IC)  (LINEAR IC)            0.121544            0.260405
# 1  (LOGIC IC, LINEAR IC)   (DISCRETE)            0.043456            0.257912
# 2   (LOGIC IC, DISCRETE)  (LINEAR IC)            0.026989            0.260405
# 3  (LINEAR IC, DISCRETE)   (LOGIC IC)            0.034907            0.121544
#
#     support  confidence      lift  leverage  conviction
# 0  0.043456    0.357529  1.372974  0.011805    1.151173
# 1  0.014714    0.338588  1.312805  0.003506    1.121975
# 2  0.014714    0.545178  2.093576  0.007686    1.626119
# 3  0.014714    0.421507  3.467931  0.010471    1.518525

# %%
from mlxtend.frequent_patterns import apriori
df1=apriori(df,min_support=0.01,use_colnames=True)
df1.sort_values(by='support',ascending=False)
# Out:
#      support                         itemsets
# 3   0.260405                      (LINEAR IC)
# 2   0.257912                       (DISCRETE)
# 4   0.121544                       (LOGIC IC)
# 9   0.119489                          (PEMCO)
# 8   0.113379                         (OTHERS)
# 1   0.110749                      (CPU / MPU)
# 5   0.066718                 (MEMORY_EMBEDED)
# 0   0.044113                  (CHIPSET / ASP)
# 12  0.043456            (LOGIC IC, LINEAR IC)
# 7   0.039866             (OPTICAL AND SENSOR)
# 10  0.034907            (LINEAR IC, DISCRETE)
# 11  0.026989             (LOGIC IC, DISCRETE)
# 6   0.021235                  (MEMORY_SYSTEM)
# 13  0.014714  (LOGIC IC, LINEAR IC, DISCRETE)
